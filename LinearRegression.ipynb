# %% [markdown]
# <a href="https://colab.research.google.com/github/Chayangowda/Linear-Regression/blob/main/LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
df = pd.read_csv("/content/home-rental.csv")

# %%
x = df[['size']]
y = df[['rent_amount']]

# %%
x_train, x_text, y_train, Y_test = train_test_split(x,y,test_size=0.2, random_state=42)

# %%
model = LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_text)

# %%
mse = mean_squared_error(Y_test,y_pred)
print("Mean Squared Error:",mse)
# Out:
# Mean Squared Error: 3781.01129644514

# %%
plt.scatter(x,y,color='blue')
plt.plot(x,model.predict(x),color='brown')
plt.xlabel('size')
plt.ylabel('rent_amount($1000)')
plt.title("Linear Regression Example")
plt.show()
